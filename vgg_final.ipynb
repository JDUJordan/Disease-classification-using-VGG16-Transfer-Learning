# %%
import keras
from keras.models import Model
from keras.layers import Dense
from keras import optimizers
from keras.preprocessing.image import ImageDataGenerator
from keras.preprocessing import image
import tensorflow as tf
import numpy as np
import matplotlib.pyplot as plt

# %% [markdown]
# Import reqiured librarys

# %%
trdata = ImageDataGenerator(validation_split=0.2)
traindata = trdata.flow_from_directory(directory=r"C:\Users\Jordan Lankford\OneDrive - University of Greenwich\AI\cw\archive\PlantVillage",target_size=(224,224),subset="training")
testdata = trdata.flow_from_directory(directory=r"C:\Users\Jordan Lankford\OneDrive - University of Greenwich\AI\cw\archive\PlantVillage", target_size=(224,224),subset = "validation")
# Out:
# Found 16515 images belonging to 15 classes.
# Found 4122 images belonging to 15 classes.

# %% [markdown]
# Use the ImageDataGenerator to retrive and preprocess my data.
# data will be fetched from file location and labels automatically applied.
# validation_split allows me to automatically split my data into a train and test sample.

# %%
traindata.class_indices
# Out:
# {'Pepper__bell___Bacterial_spot': 0,
#  'Pepper__bell___healthy': 1,
#  'Potato___Early_blight': 2,
#  'Potato___Late_blight': 3,
#  'Potato___healthy': 4,
#  'Tomato_Bacterial_spot': 5,
#  'Tomato_Early_blight': 6,
#  'Tomato_Late_blight': 7,
#  'Tomato_Leaf_Mold': 8,
#  'Tomato_Septoria_leaf_spot': 9,
#  'Tomato_Spider_mites_Two_spotted_spider_mite': 10,
#  'Tomato__Target_Spot': 11,
#  'Tomato__Tomato_YellowLeaf__Curl_Virus': 12,
#  'Tomato__Tomato_mosaic_virus': 13,
#  'Tomato_healthy': 14}

# %% [markdown]
# Output labels of our data, 15 possible classes.

# %%
from keras.applications.vgg16 import VGG16
vggmodel = VGG16(weights='imagenet', include_top=True)

# %% [markdown]
# Download the VGG architecture
# set the VGG16 architecture weights to be that of the VGG16 architecture trained More than 14 million images,
# so that we can use transfer learning and not have to directly train these layers

# %%
vggmodel.summary()
# Out:
# Model: "vgg16"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  input_1 (InputLayer)        [(None, 224, 224, 3)]     0
#
#  block1_conv1 (Conv2D)       (None, 224, 224, 64)      1792
#
#  block1_conv2 (Conv2D)       (None, 224, 224, 64)      36928
#
#  block1_pool (MaxPooling2D)  (None, 112, 112, 64)      0
#
#  block2_conv1 (Conv2D)       (None, 112, 112, 128)     73856
#
#  block2_conv2 (Conv2D)       (None, 112, 112, 128)     147584
#
#  block2_pool (MaxPooling2D)  (None, 56, 56, 128)       0
#
#  block3_conv1 (Conv2D)       (None, 56, 56, 256)       295168
#
#  block3_conv2 (Conv2D)       (None, 56, 56, 256)       590080
#
#  block3_conv3 (Conv2D)       (None, 56, 56, 256)       590080
#
#  block3_pool (MaxPooling2D)  (None, 28, 28, 256)       0
#
#  block4_conv1 (Conv2D)       (None, 28, 28, 512)       1180160
#
#  block4_conv2 (Conv2D)       (None, 28, 28, 512)       2359808
#
#  block4_conv3 (Conv2D)       (None, 28, 28, 512)       2359808
#
#  block4_pool (MaxPooling2D)  (None, 14, 14, 512)       0
#
#  block5_conv1 (Conv2D)       (None, 14, 14, 512)       2359808
#
#  block5_conv2 (Conv2D)       (None, 14, 14, 512)       2359808
#
#  block5_conv3 (Conv2D)       (None, 14, 14, 512)       2359808
#
#  block5_pool (MaxPooling2D)  (None, 7, 7, 512)         0
#
#  flatten (Flatten)           (None, 25088)             0
#
#  fc1 (Dense)                 (None, 4096)              102764544
#
#  fc2 (Dense)                 (None, 4096)              16781312
#
#  predictions (Dense)         (None, 1000)              4097000
#
# =================================================================
# Total params: 138,357,544
# Trainable params: 138,357,544
# Non-trainable params: 0
# _________________________________________________________________

# %% [markdown]
# Summary shows VGG16 convolutional nural network layout.
# currently has 1000 possible ouputs as specified by the image net dataset.

# %%
for layers in (vggmodel.layers)[:19]:
    print(layers)
    layers.trainable = False
# Out:
# <keras.engine.input_layer.InputLayer object at 0x0000017981857F40>
# <keras.layers.convolutional.conv2d.Conv2D object at 0x0000017982054F70>
# <keras.layers.convolutional.conv2d.Conv2D object at 0x00000179820551E0>
# <keras.layers.pooling.max_pooling2d.MaxPooling2D object at 0x0000017982055B70>
# <keras.layers.convolutional.conv2d.Conv2D object at 0x0000017982055900>
# <keras.layers.convolutional.conv2d.Conv2D object at 0x0000017982057760>
# <keras.layers.pooling.max_pooling2d.MaxPooling2D object at 0x0000017982057430>
# <keras.layers.convolutional.conv2d.Conv2D object at 0x0000017982057160>
# <keras.layers.convolutional.conv2d.Conv2D object at 0x00000179DA817700>
# <keras.layers.convolutional.conv2d.Conv2D object at 0x00000179DA86A020>
# <keras.layers.pooling.max_pooling2d.MaxPooling2D object at 0x0000017982056470>
# <keras.layers.convolutional.conv2d.Conv2D object at 0x00000179820558A0>
# <keras.layers.convolutional.conv2d.Conv2D object at 0x00000179820572B0>
# <keras.layers.convolutional.conv2d.Conv2D object at 0x0000017982055E70>
# <keras.layers.pooling.max_pooling2d.MaxPooling2D object at 0x00000179822A32B0>
# <keras.layers.convolutional.conv2d.Conv2D object at 0x00000179822A2EF0>
# <keras.layers.convolutional.conv2d.Conv2D object at 0x00000179822A0B80>
# <keras.layers.convolutional.conv2d.Conv2D object at 0x00000179822A2D70>
# <keras.layers.pooling.max_pooling2d.MaxPooling2D object at 0x00000179822C1990>

# %% [markdown]
# Make the first 19 layers un-trainable, so that the weights of hese layers do not change during training

# %%
X= vggmodel.layers[-2].output
predictions = Dense(15, activation="softmax")(X)
model_final = Model(vggmodel.input,predictions)

# %% [markdown]
# Create the dense layer with 15 outputs, to repreasen our 15 classes of healhy/diseseased plants

# %%
model_final.compile(loss = "categorical_crossentropy", optimizer = optimizers.SGD(learning_rate=0.0001, momentum=0.9), metrics=["accuracy"])

# %% [markdown]
# compile our model with a learning rate of 0.0001.
# use momentum to "momentum is known to speed up learning and to help not getting stuck in local minima." -https://datascience.stackexchange.com/questions/84167/what-is-momentum-in-neural-network

# %%
model_final.summary()
# Out:
# Model: "model"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  input_1 (InputLayer)        [(None, 224, 224, 3)]     0
#
#  block1_conv1 (Conv2D)       (None, 224, 224, 64)      1792
#
#  block1_conv2 (Conv2D)       (None, 224, 224, 64)      36928
#
#  block1_pool (MaxPooling2D)  (None, 112, 112, 64)      0
#
#  block2_conv1 (Conv2D)       (None, 112, 112, 128)     73856
#
#  block2_conv2 (Conv2D)       (None, 112, 112, 128)     147584
#
#  block2_pool (MaxPooling2D)  (None, 56, 56, 128)       0
#
#  block3_conv1 (Conv2D)       (None, 56, 56, 256)       295168
#
#  block3_conv2 (Conv2D)       (None, 56, 56, 256)       590080
#
#  block3_conv3 (Conv2D)       (None, 56, 56, 256)       590080
#
#  block3_pool (MaxPooling2D)  (None, 28, 28, 256)       0
#
#  block4_conv1 (Conv2D)       (None, 28, 28, 512)       1180160
#
#  block4_conv2 (Conv2D)       (None, 28, 28, 512)       2359808
#
#  block4_conv3 (Conv2D)       (None, 28, 28, 512)       2359808
#
#  block4_pool (MaxPooling2D)  (None, 14, 14, 512)       0
#
#  block5_conv1 (Conv2D)       (None, 14, 14, 512)       2359808
#
#  block5_conv2 (Conv2D)       (None, 14, 14, 512)       2359808
#
#  block5_conv3 (Conv2D)       (None, 14, 14, 512)       2359808
#
#  block5_pool (MaxPooling2D)  (None, 7, 7, 512)         0
#
#  flatten (Flatten)           (None, 25088)             0
#
#  fc1 (Dense)                 (None, 4096)              102764544
#
#  fc2 (Dense)                 (None, 4096)              16781312
#
#  dense (Dense)               (None, 15)                61455
#
# =================================================================
# Total params: 134,321,999
# Trainable params: 119,607,311
# Non-trainable params: 14,714,688
# _________________________________________________________________

# %%
batchSize=32
steps = int(16515/batchSize)
print(steps)
# Out:
# 516

# %%
from keras.callbacks import ModelCheckpoint, EarlyStopping
checkpoint = ModelCheckpoint(r"C:\Users\Jordan Lankford\OneDrive - University of Greenwich/AI/cw/my_model_usingsave.h5", monitor='val_acc', verbose=1, save_best_only=True, save_weights_only=False, mode='auto', period=1)
early = EarlyStopping(monitor='accuracy', min_delta=0, patience=40, verbose=1, mode='auto')
history = model_final.fit(traindata, batch_size = batchSize,steps_per_epoch= steps, epochs= 50, validation_data= testdata, validation_steps=1, callbacks=[checkpoint,early])
model_final.save_weights("vgg16_1.h5")
# Out:
# WARNING:tensorflow:`period` argument is deprecated. Please use `save_freq` to specify the frequency in number of batches seen.
# Epoch 1/50
# 516/516 [==============================] - ETA: 0s - loss: 0.0827 - accuracy: 0.9779WARNING:tensorflow:Can save best model only with val_acc available, skipping.
# 516/516 [==============================] - 2232s 4s/step - loss: 0.0827 - accuracy: 0.9779 - val_loss: 0.2148 - val_accuracy: 0.9375
# Epoch 2/50
# 516/516 [==============================] - ETA: 0s - loss: 0.0393 - accuracy: 0.9948WARNING:tensorflow:Can save best model only with val_acc available, skipping.
# 516/516 [==============================] - 2225s 4s/step - loss: 0.0393 - accuracy: 0.9948 - val_loss: 0.2800 - val_accuracy: 0.8750
# Epoch 3/50
# 516/516 [==============================] - ETA: 0s - loss: 0.0224 - accuracy: 0.9986WARNING:tensorflow:Can save best model only with val_acc available, skipping.
# 516/516 [==============================] - 2282s 4s/step - loss: 0.0224 - accuracy: 0.9986 - val_loss: 0.0946 - val_accuracy: 0.9688
# Epoch 4/50
# 516/516 [==============================] - ETA: 0s - loss: 0.0154 - accuracy: 0.9996WARNING:tensorflow:Can save best model only with val_acc available, skipping.
# 516/516 [==============================] - 2249s 4s/step - loss: 0.0154 - accuracy: 0.9996 - val_loss: 0.1290 - val_accuracy: 0.9375
# Epoch 5/50
# 516/516 [==============================] - ETA: 0s - loss: 0.0110 - accuracy: 0.9999WARNING:tensorflow:Can save best model only with val_acc available, skipping.
# 516/516 [==============================] - 2251s 4s/step - loss: 0.0110 - accuracy: 0.9999 - val_loss: 0.3195 - val_accuracy: 0.9375
# Epoch 6/50
# 516/516 [==============================] - ETA: 0s - loss: 0.0088 - accuracy: 0.9999WARNING:tensorflow:Can save best model only with val_acc available, skipping.
# 516/516 [==============================] - 2468s 5s/step - loss: 0.0088 - accuracy: 0.9999 - val_loss: 0.4399 - val_accuracy: 0.9375
# Epoch 7/50
# 516/516 [==============================] - ETA: 0s - loss: 0.0072 - accuracy: 0.9999WARNING:tensorflow:Can save best model only with val_acc available, skipping.
# 516/516 [==============================] - 2454s 5s/step - loss: 0.0072 - accuracy: 0.9999 - val_loss: 0.0989 - val_accuracy: 0.9688
# Epoch 8/50
# 516/516 [==============================] - ETA: 0s - loss: 0.0062 - accuracy: 1.0000WARNING:tensorflow:Can save best model only with val_acc available, skipping.
# 516/516 [==============================] - 2469s 5s/step - loss: 0.0062 - accuracy: 1.0000 - val_loss: 0.0194 - val_accuracy: 1.0000
# Epoch 9/50
# 516/516 [==============================] - ETA: 0s - loss: 0.0053 - accuracy: 1.0000WARNING:tensorflow:Can save best model only with val_acc available, skipping.
# 516/516 [==============================] - 2360s 5s/step - loss: 0.0053 - accuracy: 1.0000 - val_loss: 0.0054 - val_accuracy: 1.0000
# Epoch 10/50
# 516/516 [==============================] - ETA: 0s - loss: 0.0047 - accuracy: 1.0000WARNING:tensorflow:Can save best model only with val_acc available, skipping.
# 516/516 [==============================] - 2323s 5s/step - loss: 0.0047 - accuracy: 1.0000 - val_loss: 0.2007 - val_accuracy: 0.9062
# Epoch 11/50
# 516/516 [==============================] - ETA: 0s - loss: 0.0043 - accuracy: 1.0000WARNING:tensorflow:Can save best model only with val_acc available, skipping.
# 516/516 [==============================] - 2272s 4s/step - loss: 0.0043 - accuracy: 1.0000 - val_loss: 0.0263 - val_accuracy: 1.0000
# Epoch 12/50
# 516/516 [==============================] - ETA: 0s - loss: 0.0039 - accuracy: 1.0000WARNING:tensorflow:Can save best model only with val_acc available, skipping.
# 516/516 [==============================] - 2259s 4s/step - loss: 0.0039 - accuracy: 1.0000 - val_loss: 0.1684 - val_accuracy: 0.9688
# Epoch 13/50
# 516/516 [==============================] - ETA: 0s - loss: 0.0035 - accuracy: 1.0000WARNING:tensorflow:Can save best model only with val_acc available, skipping.
# 516/516 [==============================] - 2245s 4s/step - loss: 0.0035 - accuracy: 1.0000 - val_loss: 0.3792 - val_accuracy: 0.9062
# Epoch 14/50
# 516/516 [==============================] - ETA: 0s - loss: 0.0032 - accuracy: 1.0000WARNING:tensorflow:Can save best model only with val_acc available, skipping.
# 516/516 [==============================] - 2276s 4s/step - loss: 0.0032 - accuracy: 1.0000 - val_loss: 0.0248 - val_accuracy: 1.0000
# Epoch 15/50
# 516/516 [==============================] - ETA: 0s - loss: 0.0030 - accuracy: 1.0000WARNING:tensorflow:Can save best model only with val_acc available, skipping.
# 516/516 [==============================] - 2238s 4s/step - loss: 0.0030 - accuracy: 1.0000 - val_loss: 0.4128 - val_accuracy: 0.9062
# Epoch 16/50
# 516/516 [==============================] - ETA: 0s - loss: 0.0028 - accuracy: 1.0000WARNING:tensorflow:Can save best model only with val_acc available, skipping.
# 516/516 [==============================] - 2244s 4s/step - loss: 0.0028 - accuracy: 1.0000 - val_loss: 0.3809 - val_accuracy: 0.8750
# Epoch 17/50
# 516/516 [==============================] - ETA: 0s - loss: 0.0026 - accuracy: 1.0000WARNING:tensorflow:Can save best model only with val_acc available, skipping.
# 516/516 [==============================] - 2289s 4s/step - loss: 0.0026 - accuracy: 1.0000 - val_loss: 0.2205 - val_accuracy: 0.9062
# Epoch 18/50
# 516/516 [==============================] - ETA: 0s - loss: 0.0024 - accuracy: 1.0000WARNING:tensorflow:Can save best model only with val_acc available, skipping.
# 516/516 [==============================] - 2319s 4s/step - loss: 0.0024 - accuracy: 1.0000 - val_loss: 0.1995 - val_accuracy: 0.9375
# Epoch 19/50
# 516/516 [==============================] - ETA: 0s - loss: 0.0023 - accuracy: 1.0000WARNING:tensorflow:Can save best model only with val_acc available, skipping.
# 516/516 [==============================] - 2273s 4s/step - loss: 0.0023 - accuracy: 1.0000 - val_loss: 0.5180 - val_accuracy: 0.8750
# Epoch 20/50
# 516/516 [==============================] - ETA: 0s - loss: 0.0022 - accuracy: 1.0000WARNING:tensorflow:Can save best model only with val_acc available, skipping.
# 516/516 [==============================] - 2297s 4s/step - loss: 0.0022 - accuracy: 1.0000 - val_loss: 0.5926 - val_accuracy: 0.9062
# Epoch 21/50
# 516/516 [==============================] - ETA: 0s - loss: 0.0021 - accuracy: 1.0000WARNING:tensorflow:Can save best model only with val_acc available, skipping.
# 516/516 [==============================] - 2312s 4s/step - loss: 0.0021 - accuracy: 1.0000 - val_loss: 0.0787 - val_accuracy: 0.9375
# Epoch 22/50
# 516/516 [==============================] - ETA: 0s - loss: 0.0019 - accuracy: 1.0000WARNING:tensorflow:Can save best model only with val_acc available, skipping.
# 516/516 [==============================] - 2260s 4s/step - loss: 0.0019 - accuracy: 1.0000 - val_loss: 0.2199 - val_accuracy: 0.8750
# Epoch 23/50
# 516/516 [==============================] - ETA: 0s - loss: 0.0019 - accuracy: 1.0000WARNING:tensorflow:Can save best model only with val_acc available, skipping.
# 516/516 [==============================] - 2297s 4s/step - loss: 0.0019 - accuracy: 1.0000 - val_loss: 0.0957 - val_accuracy: 0.9688
# Epoch 24/50
# 516/516 [==============================] - ETA: 0s - loss: 0.0018 - accuracy: 1.0000WARNING:tensorflow:Can save best model only with val_acc available, skipping.
# 516/516 [==============================] - 2269s 4s/step - loss: 0.0018 - accuracy: 1.0000 - val_loss: 0.0639 - val_accuracy: 0.9688
# Epoch 25/50
# 516/516 [==============================] - ETA: 0s - loss: 0.0017 - accuracy: 1.0000WARNING:tensorflow:Can save best model only with val_acc available, skipping.
# 516/516 [==============================] - 2259s 4s/step - loss: 0.0017 - accuracy: 1.0000 - val_loss: 0.1525 - val_accuracy: 0.9688
# Epoch 26/50
# 516/516 [==============================] - ETA: 0s - loss: 0.0016 - accuracy: 1.0000WARNING:tensorflow:Can save best model only with val_acc available, skipping.
# 516/516 [==============================] - 2272s 4s/step - loss: 0.0016 - accuracy: 1.0000 - val_loss: 0.4776 - val_accuracy: 0.8750
# Epoch 27/50
# 516/516 [==============================] - ETA: 0s - loss: 0.0015 - accuracy: 1.0000WARNING:tensorflow:Can save best model only with val_acc available, skipping.
# 516/516 [==============================] - 2265s 4s/step - loss: 0.0015 - accuracy: 1.0000 - val_loss: 0.1647 - val_accuracy: 0.9375
# Epoch 28/50
# 516/516 [==============================] - ETA: 0s - loss: 0.0015 - accuracy: 1.0000WARNING:tensorflow:Can save best model only with val_acc available, skipping.
# 516/516 [==============================] - 2288s 4s/step - loss: 0.0015 - accuracy: 1.0000 - val_loss: 0.0106 - val_accuracy: 1.0000
# Epoch 29/50
# 516/516 [==============================] - ETA: 0s - loss: 0.0014 - accuracy: 1.0000WARNING:tensorflow:Can save best model only with val_acc available, skipping.
# 516/516 [==============================] - 2325s 5s/step - loss: 0.0014 - accuracy: 1.0000 - val_loss: 0.2636 - val_accuracy: 0.8750
# Epoch 30/50
# 516/516 [==============================] - ETA: 0s - loss: 0.0014 - accuracy: 1.0000WARNING:tensorflow:Can save best model only with val_acc available, skipping.
# 516/516 [==============================] - 2290s 4s/step - loss: 0.0014 - accuracy: 1.0000 - val_loss: 0.0246 - val_accuracy: 1.0000
# Epoch 31/50
# 516/516 [==============================] - ETA: 0s - loss: 0.0013 - accuracy: 1.0000WARNING:tensorflow:Can save best model only with val_acc available, skipping.
# 516/516 [==============================] - 2319s 4s/step - loss: 0.0013 - accuracy: 1.0000 - val_loss: 0.1953 - val_accuracy: 0.9062
# Epoch 32/50
# 516/516 [==============================] - ETA: 0s - loss: 0.0013 - accuracy: 1.0000WARNING:tensorflow:Can save best model only with val_acc available, skipping.
# 516/516 [==============================] - 2270s 4s/step - loss: 0.0013 - accuracy: 1.0000 - val_loss: 0.1038 - val_accuracy: 0.9688
# Epoch 33/50
# 516/516 [==============================] - ETA: 0s - loss: 0.0012 - accuracy: 1.0000WARNING:tensorflow:Can save best model only with val_acc available, skipping.
# 516/516 [==============================] - 2356s 5s/step - loss: 0.0012 - accuracy: 1.0000 - val_loss: 0.1425 - val_accuracy: 0.9062
# Epoch 34/50
# 516/516 [==============================] - ETA: 0s - loss: 0.0012 - accuracy: 1.0000WARNING:tensorflow:Can save best model only with val_acc available, skipping.
# 516/516 [==============================] - 2291s 4s/step - loss: 0.0012 - accuracy: 1.0000 - val_loss: 0.5576 - val_accuracy: 0.7812
# Epoch 35/50
# 516/516 [==============================] - ETA: 0s - loss: 0.0012 - accuracy: 1.0000WARNING:tensorflow:Can save best model only with val_acc available, skipping.
# 516/516 [==============================] - 2250s 4s/step - loss: 0.0012 - accuracy: 1.0000 - val_loss: 0.0994 - val_accuracy: 0.9688
# Epoch 36/50
# 516/516 [==============================] - ETA: 0s - loss: 0.0011 - accuracy: 1.0000WARNING:tensorflow:Can save best model only with val_acc available, skipping.
# 516/516 [==============================] - 2248s 4s/step - loss: 0.0011 - accuracy: 1.0000 - val_loss: 0.2129 - val_accuracy: 0.9375
# Epoch 37/50
# 516/516 [==============================] - ETA: 0s - loss: 0.0011 - accuracy: 1.0000WARNING:tensorflow:Can save best model only with val_acc available, skipping.
# 516/516 [==============================] - 2240s 4s/step - loss: 0.0011 - accuracy: 1.0000 - val_loss: 0.0184 - val_accuracy: 1.0000
# Epoch 38/50
# 516/516 [==============================] - ETA: 0s - loss: 0.0011 - accuracy: 1.0000WARNING:tensorflow:Can save best model only with val_acc available, skipping.
# 516/516 [==============================] - 2354s 5s/step - loss: 0.0011 - accuracy: 1.0000 - val_loss: 0.0977 - val_accuracy: 0.9688
# Epoch 39/50
# 516/516 [==============================] - ETA: 0s - loss: 0.0010 - accuracy: 1.0000WARNING:tensorflow:Can save best model only with val_acc available, skipping.
# 516/516 [==============================] - 2345s 5s/step - loss: 0.0010 - accuracy: 1.0000 - val_loss: 0.2867 - val_accuracy: 0.9688
# Epoch 40/50
# 516/516 [==============================] - ETA: 0s - loss: 9.9429e-04 - accuracy: 1.0000WARNING:tensorflow:Can save best model only with val_acc available, skipping.
# 516/516 [==============================] - 2416s 5s/step - loss: 9.9429e-04 - accuracy: 1.0000 - val_loss: 0.0818 - val_accuracy: 0.9688
# Epoch 41/50
# 516/516 [==============================] - ETA: 0s - loss: 9.6491e-04 - accuracy: 1.0000WARNING:tensorflow:Can save best model only with val_acc available, skipping.
# 516/516 [==============================] - 2705s 5s/step - loss: 9.6491e-04 - accuracy: 1.0000 - val_loss: 0.0180 - val_accuracy: 1.0000
# Epoch 42/50
# 516/516 [==============================] - ETA: 0s - loss: 9.3702e-04 - accuracy: 1.0000WARNING:tensorflow:Can save best model only with val_acc available, skipping.
# 516/516 [==============================] - 2662s 5s/step - loss: 9.3702e-04 - accuracy: 1.0000 - val_loss: 0.0277 - val_accuracy: 0.9688
# Epoch 43/50
# 516/516 [==============================] - ETA: 0s - loss: 9.1463e-04 - accuracy: 1.0000WARNING:tensorflow:Can save best model only with val_acc available, skipping.
# 516/516 [==============================] - 2600s 5s/step - loss: 9.1463e-04 - accuracy: 1.0000 - val_loss: 0.2995 - val_accuracy: 0.9375
# Epoch 44/50
# 516/516 [==============================] - ETA: 0s - loss: 8.8959e-04 - accuracy: 1.0000WARNING:tensorflow:Can save best model only with val_acc available, skipping.
# 516/516 [==============================] - 2484s 5s/step - loss: 8.8959e-04 - accuracy: 1.0000 - val_loss: 0.0649 - val_accuracy: 0.9688
# Epoch 45/50
# 516/516 [==============================] - ETA: 0s - loss: 8.6801e-04 - accuracy: 1.0000WARNING:tensorflow:Can save best model only with val_acc available, skipping.
# 516/516 [==============================] - 2270s 4s/step - loss: 8.6801e-04 - accuracy: 1.0000 - val_loss: 0.3202 - val_accuracy: 0.9688
# Epoch 46/50
# 516/516 [==============================] - ETA: 0s - loss: 8.4718e-04 - accuracy: 1.0000WARNING:tensorflow:Can save best model only with val_acc available, skipping.
# 516/516 [==============================] - 2272s 4s/step - loss: 8.4718e-04 - accuracy: 1.0000 - val_loss: 0.2397 - val_accuracy: 0.9375
# Epoch 47/50
# 516/516 [==============================] - ETA: 0s - loss: 8.2554e-04 - accuracy: 1.0000WARNING:tensorflow:Can save best model only with val_acc available, skipping.
# 516/516 [==============================] - 2257s 4s/step - loss: 8.2554e-04 - accuracy: 1.0000 - val_loss: 0.0173 - val_accuracy: 1.0000
# Epoch 48/50
# 516/516 [==============================] - ETA: 0s - loss: 8.0761e-04 - accuracy: 1.0000WARNING:tensorflow:Can save best model only with val_acc available, skipping.
# 516/516 [==============================] - 2229s 4s/step - loss: 8.0761e-04 - accuracy: 1.0000 - val_loss: 0.0710 - val_accuracy: 0.9688
# Epoch 48: early stopping

# %%
model_final.save("final.128.h5")

# %%
print(history)
np.save('my_history.128.npy',history.history)
# Out:
# <keras.callbacks.History object at 0x00000179932C66E0>

# %%
import keras
from matplotlib import pyplot as plt
plt.plot(history.history['accuracy'])
plt.plot(history.history['val_accuracy'])
plt.title('model accuracy')
plt.ylabel('accuracy')
plt.xlabel('epoch')
plt.legend(['train', 'val'], loc='upper left')
plt.show()

# %%
from keras.preprocessing import image
img = keras.utils.load_img(r"C:\Users\Jordan Lankford\OneDrive - University of Greenwich\AI\cw\just_peppers\predict\tom_mosaic.JPG",target_size=(224,224))
img = np.asarray(img)
plt.imshow(img)
img = np.expand_dims(img, axis=0)
from keras.models import load_model
saved_model = load_model(r"C:\Users\Jordan Lankford\OneDrive - University of Greenwich/AI/cw/my_model_usingsave.h5")
output = saved_model.predict(img)
print(output)
result = np.where(output == np.amax(output))
# print('max probabilliy:', result[1])
# print('found at index :', result[0])
value = {i for i in traindata.class_indices if traindata.class_indices[i]==result[1]}
print("label:",value)
# Out:
# 1/1 [==============================] - 1s 1s/step
# [[1.00655176e-04 4.90058737e-04 2.18274043e-04 3.72114801e-03
#   1.32400566e-03 1.37675237e-02 5.17022330e-03 2.10660929e-03
#   3.37525494e-02 6.46121427e-02 1.76428407e-01 2.26755396e-01
#   1.02686910e-02 4.42454129e-01 1.88301764e-02]]
# label: {'Tomato__Tomato_mosaic_virus'}

# %%
from keras.models import load_model
saved_model = load_model(r"C:\Users\Jordan Lankford\OneDrive - University of Greenwich/AI/cw/final.128.h5")
test_score = saved_model.evaluate_generator(testdata, 2)
print("[INFO] accuracy: {:.2f}%".format(test_score[1] * 100))
print("[INFO] Loss: ",test_score[0])
# Out:
# C:\Users\Jordan Lankford\AppData\Local\Temp\ipykernel_22488\1204721946.py:3: UserWarning: `Model.evaluate_generator` is deprecated and will be removed in a future version. Please use `Model.evaluate`, which supports generators.
#   test_score = saved_model.evaluate_generator(testdata, 2)
# [INFO] accuracy: 98.44%
# [INFO] Loss:  0.15916241705417633

# %% [markdown]
# Function to show label assigend to one given input.

# %% [markdown]
# Predicions - CM

# %%
Y_pred = saved_model.predict(testdata)
# Out:
# 129/129 [==============================] - 783s 6s/step

# %% [markdown]
# FINE TUNING

# %%
from keras.models import load_model
saved_model = load_model(r"C:\Users\Jordan Lankford\OneDrive - University of Greenwich/AI/cw/final.1.h5")

# %%
# Freeze four convolution blocks
for layer in saved_model.layers[15:]:
    layer.trainable = True

# Make sure you have frozen the correct layers
for i, layer in enumerate(saved_model.layers):
    print(i, layer.name, layer.trainable)
# Out:
# 0 input_1 True
# 1 block1_conv1 False
# 2 block1_conv2 False
# 3 block1_pool False
# 4 block2_conv1 False
# 5 block2_conv2 False
# 6 block2_pool False
# 7 block3_conv1 False
# 8 block3_conv2 False
# 9 block3_conv3 False
# 10 block3_pool False
# 11 block4_conv1 False
# 12 block4_conv2 False
# 13 block4_conv3 False
# 14 block4_pool False
# 15 block5_conv1 True
# 16 block5_conv2 True
# 17 block5_conv3 True
# 18 block5_pool True
# 19 flatten True
# 20 fc1 True
# 21 fc2 True
# 22 dense True

# %% [markdown]
# Make last CNN block trainable
# aswell as my added top layers for transfer learning

# %%
from keras.callbacks import ModelCheckpoint, EarlyStopping
checkpoint = ModelCheckpoint(r"C:\Users\Jordan Lankford\OneDrive - University of Greenwich/AI/cw/my_model_usingsave.h5", monitor='val_acc', verbose=1, save_best_only=True, save_weights_only=False, mode='auto', period=1)
early = EarlyStopping(monitor='val_acc', min_delta=0, patience=40, verbose=1, mode='auto')
tuneHistory = saved_model.fit_generator(generator= traindata, steps_per_epoch= 10, epochs= 30, validation_data= testdata, validation_steps=1, callbacks=[checkpoint,early])
# Out:
# WARNING:tensorflow:`period` argument is deprecated. Please use `save_freq` to specify the frequency in number of batches seen.
# C:\Users\Jordan Lankford\AppData\Local\Temp\ipykernel_19364\240515080.py:4: UserWarning: `Model.fit_generator` is deprecated and will be removed in a future version. Please use `Model.fit`, which supports generators.
#   tuneHistory = saved_model.fit_generator(generator= traindata, steps_per_epoch= 10, epochs= 30, validation_data= testdata, validation_steps=1, callbacks=[checkpoint,early])
# Epoch 1/30
# 10/10 [==============================] - ETA: 0s - loss: 0.0994 - accuracy: 0.9750WARNING:tensorflow:Can save best model only with val_acc available, skipping.
# WARNING:tensorflow:Early stopping conditioned on metric `val_acc` which is not available. Available metrics are: loss,accuracy,val_loss,val_accuracy
# 10/10 [==============================] - 46s 5s/step - loss: 0.0994 - accuracy: 0.9750 - val_loss: 0.4500 - val_accuracy: 0.8750
# Epoch 2/30
# 10/10 [==============================] - ETA: 0s - loss: 0.1009 - accuracy: 0.9781WARNING:tensorflow:Can save best model only with val_acc available, skipping.
# WARNING:tensorflow:Early stopping conditioned on metric `val_acc` which is not available. Available metrics are: loss,accuracy,val_loss,val_accuracy
# 10/10 [==============================] - 48s 5s/step - loss: 0.1009 - accuracy: 0.9781 - val_loss: 0.2633 - val_accuracy: 0.9062
# Epoch 3/30
# 10/10 [==============================] - ETA: 0s - loss: 0.0871 - accuracy: 0.9781WARNING:tensorflow:Can save best model only with val_acc available, skipping.
# WARNING:tensorflow:Early stopping conditioned on metric `val_acc` which is not available. Available metrics are: loss,accuracy,val_loss,val_accuracy
# 10/10 [==============================] - 50s 5s/step - loss: 0.0871 - accuracy: 0.9781 - val_loss: 0.3138 - val_accuracy: 0.9062
# Epoch 4/30
# 10/10 [==============================] - ETA: 0s - loss: 0.1363 - accuracy: 0.9625WARNING:tensorflow:Can save best model only with val_acc available, skipping.
# WARNING:tensorflow:Early stopping conditioned on metric `val_acc` which is not available. Available metrics are: loss,accuracy,val_loss,val_accuracy
# 10/10 [==============================] - 50s 5s/step - loss: 0.1363 - accuracy: 0.9625 - val_loss: 0.1828 - val_accuracy: 0.9375
# Epoch 5/30
# 10/10 [==============================] - ETA: 0s - loss: 0.1075 - accuracy: 0.9594WARNING:tensorflow:Can save best model only with val_acc available, skipping.
# WARNING:tensorflow:Early stopping conditioned on metric `val_acc` which is not available. Available metrics are: loss,accuracy,val_loss,val_accuracy
# 10/10 [==============================] - 49s 5s/step - loss: 0.1075 - accuracy: 0.9594 - val_loss: 0.2665 - val_accuracy: 0.8438
# Epoch 6/30
# 10/10 [==============================] - ETA: 0s - loss: 0.1176 - accuracy: 0.9750WARNING:tensorflow:Can save best model only with val_acc available, skipping.
# WARNING:tensorflow:Early stopping conditioned on metric `val_acc` which is not available. Available metrics are: loss,accuracy,val_loss,val_accuracy
# 10/10 [==============================] - 51s 5s/step - loss: 0.1176 - accuracy: 0.9750 - val_loss: 0.1371 - val_accuracy: 0.9375
# Epoch 7/30
# 10/10 [==============================] - ETA: 0s - loss: 0.1006 - accuracy: 0.9750WARNING:tensorflow:Can save best model only with val_acc available, skipping.
# WARNING:tensorflow:Early stopping conditioned on metric `val_acc` which is not available. Available metrics are: loss,accuracy,val_loss,val_accuracy
# 10/10 [==============================] - 48s 5s/step - loss: 0.1006 - accuracy: 0.9750 - val_loss: 0.1514 - val_accuracy: 0.9375
# Epoch 8/30
# 10/10 [==============================] - ETA: 0s - loss: 0.1426 - accuracy: 0.9656WARNING:tensorflow:Can save best model only with val_acc available, skipping.
# WARNING:tensorflow:Early stopping conditioned on metric `val_acc` which is not available. Available metrics are: loss,accuracy,val_loss,val_accuracy
# 10/10 [==============================] - 50s 5s/step - loss: 0.1426 - accuracy: 0.9656 - val_loss: 0.0923 - val_accuracy: 0.9375
# Epoch 9/30
# 10/10 [==============================] - ETA: 0s - loss: 0.1258 - accuracy: 0.9656WARNING:tensorflow:Can save best model only with val_acc available, skipping.
# WARNING:tensorflow:Early stopping conditioned on metric `val_acc` which is not available. Available metrics are: loss,accuracy,val_loss,val_accuracy
# 10/10 [==============================] - 49s 5s/step - loss: 0.1258 - accuracy: 0.9656 - val_loss: 0.3577 - val_accuracy: 0.8750
# Epoch 10/30
# 10/10 [==============================] - ETA: 0s - loss: 0.0957 - accuracy: 0.9781WARNING:tensorflow:Can save best model only with val_acc available, skipping.
# WARNING:tensorflow:Early stopping conditioned on metric `val_acc` which is not available. Available metrics are: loss,accuracy,val_loss,val_accuracy
# 10/10 [==============================] - 49s 5s/step - loss: 0.0957 - accuracy: 0.9781 - val_loss: 0.2416 - val_accuracy: 0.9062
# Epoch 11/30
# 10/10 [==============================] - ETA: 0s - loss: 0.0912 - accuracy: 0.9719WARNING:tensorflow:Can save best model only with val_acc available, skipping.
# WARNING:tensorflow:Early stopping conditioned on metric `val_acc` which is not available. Available metrics are: loss,accuracy,val_loss,val_accuracy
# 10/10 [==============================] - 50s 5s/step - loss: 0.0912 - accuracy: 0.9719 - val_loss: 0.1686 - val_accuracy: 0.9375
# Epoch 12/30
# 10/10 [==============================] - ETA: 0s - loss: 0.1540 - accuracy: 0.9563WARNING:tensorflow:Can save best model only with val_acc available, skipping.
# WARNING:tensorflow:Early stopping conditioned on metric `val_acc` which is not available. Available metrics are: loss,accuracy,val_loss,val_accuracy
# 10/10 [==============================] - 51s 5s/step - loss: 0.1540 - accuracy: 0.9563 - val_loss: 0.2421 - val_accuracy: 0.9375
# Epoch 13/30
# 10/10 [==============================] - ETA: 0s - loss: 0.1199 - accuracy: 0.9719WARNING:tensorflow:Can save best model only with val_acc available, skipping.
# WARNING:tensorflow:Early stopping conditioned on metric `val_acc` which is not available. Available metrics are: loss,accuracy,val_loss,val_accuracy
# 10/10 [==============================] - 51s 5s/step - loss: 0.1199 - accuracy: 0.9719 - val_loss: 0.1266 - val_accuracy: 0.9375
# Epoch 14/30
# 10/10 [==============================] - ETA: 0s - loss: 0.0988 - accuracy: 0.9875WARNING:tensorflow:Can save best model only with val_acc available, skipping.
# WARNING:tensorflow:Early stopping conditioned on metric `val_acc` which is not available. Available metrics are: loss,accuracy,val_loss,val_accuracy
# 10/10 [==============================] - 49s 5s/step - loss: 0.0988 - accuracy: 0.9875 - val_loss: 0.2424 - val_accuracy: 0.9062
# Epoch 15/30
# 10/10 [==============================] - ETA: 0s - loss: 0.0958 - accuracy: 0.9781WARNING:tensorflow:Can save best model only with val_acc available, skipping.
# WARNING:tensorflow:Early stopping conditioned on metric `val_acc` which is not available. Available metrics are: loss,accuracy,val_loss,val_accuracy
# 10/10 [==============================] - 51s 5s/step - loss: 0.0958 - accuracy: 0.9781 - val_loss: 0.1900 - val_accuracy: 0.9062
# Epoch 16/30
# 10/10 [==============================] - ETA: 0s - loss: 0.0707 - accuracy: 0.9844WARNING:tensorflow:Can save best model only with val_acc available, skipping.
# WARNING:tensorflow:Early stopping conditioned on metric `val_acc` which is not available. Available metrics are: loss,accuracy,val_loss,val_accuracy
# 10/10 [==============================] - 50s 5s/step - loss: 0.0707 - accuracy: 0.9844 - val_loss: 0.2412 - val_accuracy: 0.9375
# Epoch 17/30
# 10/10 [==============================] - ETA: 0s - loss: 0.0990 - accuracy: 0.9719WARNING:tensorflow:Can save best model only with val_acc available, skipping.
# WARNING:tensorflow:Early stopping conditioned on metric `val_acc` which is not available. Available metrics are: loss,accuracy,val_loss,val_accuracy
# 10/10 [==============================] - 51s 5s/step - loss: 0.0990 - accuracy: 0.9719 - val_loss: 0.1918 - val_accuracy: 0.9688
# Epoch 18/30
# 10/10 [==============================] - ETA: 0s - loss: 0.0642 - accuracy: 0.9906WARNING:tensorflow:Can save best model only with val_acc available, skipping.
# WARNING:tensorflow:Early stopping conditioned on metric `val_acc` which is not available. Available metrics are: loss,accuracy,val_loss,val_accuracy
# 10/10 [==============================] - 51s 5s/step - loss: 0.0642 - accuracy: 0.9906 - val_loss: 0.5507 - val_accuracy: 0.7812
# Epoch 19/30
# 10/10 [==============================] - ETA: 0s - loss: 0.0686 - accuracy: 0.9844WARNING:tensorflow:Can save best model only with val_acc available, skipping.
# WARNING:tensorflow:Early stopping conditioned on metric `val_acc` which is not available. Available metrics are: loss,accuracy,val_loss,val_accuracy
# 10/10 [==============================] - 51s 5s/step - loss: 0.0686 - accuracy: 0.9844 - val_loss: 0.2537 - val_accuracy: 0.8750
# Epoch 20/30
# 10/10 [==============================] - ETA: 0s - loss: 0.0837 - accuracy: 0.9781WARNING:tensorflow:Can save best model only with val_acc available, skipping.
# WARNING:tensorflow:Early stopping conditioned on metric `val_acc` which is not available. Available metrics are: loss,accuracy,val_loss,val_accuracy
# 10/10 [==============================] - 51s 5s/step - loss: 0.0837 - accuracy: 0.9781 - val_loss: 0.2577 - val_accuracy: 0.8438
# Epoch 21/30
# 10/10 [==============================] - ETA: 0s - loss: 0.0742 - accuracy: 0.9906WARNING:tensorflow:Can save best model only with val_acc available, skipping.
# WARNING:tensorflow:Early stopping conditioned on metric `val_acc` which is not available. Available metrics are: loss,accuracy,val_loss,val_accuracy
# 10/10 [==============================] - 50s 5s/step - loss: 0.0742 - accuracy: 0.9906 - val_loss: 0.4005 - val_accuracy: 0.8750
# Epoch 22/30
# 10/10 [==============================] - ETA: 0s - loss: 0.0732 - accuracy: 0.9844WARNING:tensorflow:Can save best model only with val_acc available, skipping.
# WARNING:tensorflow:Early stopping conditioned on metric `val_acc` which is not available. Available metrics are: loss,accuracy,val_loss,val_accuracy
# 10/10 [==============================] - 50s 5s/step - loss: 0.0732 - accuracy: 0.9844 - val_loss: 0.3074 - val_accuracy: 0.8438
# Epoch 23/30
# 10/10 [==============================] - ETA: 0s - loss: 0.0783 - accuracy: 0.9781WARNING:tensorflow:Can save best model only with val_acc available, skipping.
# WARNING:tensorflow:Early stopping conditioned on metric `val_acc` which is not available. Available metrics are: loss,accuracy,val_loss,val_accuracy
# 10/10 [==============================] - 51s 5s/step - loss: 0.0783 - accuracy: 0.9781 - val_loss: 0.0817 - val_accuracy: 1.0000
# Epoch 24/30
# 10/10 [==============================] - ETA: 0s - loss: 0.0927 - accuracy: 0.9750WARNING:tensorflow:Can save best model only with val_acc available, skipping.
# WARNING:tensorflow:Early stopping conditioned on metric `val_acc` which is not available. Available metrics are: loss,accuracy,val_loss,val_accuracy
# 10/10 [==============================] - 56s 6s/step - loss: 0.0927 - accuracy: 0.9750 - val_loss: 0.1681 - val_accuracy: 0.9375
# Epoch 25/30
# 10/10 [==============================] - ETA: 0s - loss: 0.0664 - accuracy: 0.9844WARNING:tensorflow:Can save best model only with val_acc available, skipping.
# WARNING:tensorflow:Early stopping conditioned on metric `val_acc` which is not available. Available metrics are: loss,accuracy,val_loss,val_accuracy
# 10/10 [==============================] - 52s 5s/step - loss: 0.0664 - accuracy: 0.9844 - val_loss: 0.2739 - val_accuracy: 0.9375
# Epoch 26/30
# 10/10 [==============================] - ETA: 0s - loss: 0.0627 - accuracy: 0.9844WARNING:tensorflow:Can save best model only with val_acc available, skipping.
# WARNING:tensorflow:Early stopping conditioned on metric `val_acc` which is not available. Available metrics are: loss,accuracy,val_loss,val_accuracy
# 10/10 [==============================] - 50s 5s/step - loss: 0.0627 - accuracy: 0.9844 - val_loss: 0.3217 - val_accuracy: 0.9062
# Epoch 27/30
# 10/10 [==============================] - ETA: 0s - loss: 0.0650 - accuracy: 0.9937WARNING:tensorflow:Can save best model only with val_acc available, skipping.
# WARNING:tensorflow:Early stopping conditioned on metric `val_acc` which is not available. Available metrics are: loss,accuracy,val_loss,val_accuracy
# 10/10 [==============================] - 53s 5s/step - loss: 0.0650 - accuracy: 0.9937 - val_loss: 0.1904 - val_accuracy: 0.9375
# Epoch 28/30
# 10/10 [==============================] - ETA: 0s - loss: 0.0786 - accuracy: 0.9812WARNING:tensorflow:Can save best model only with val_acc available, skipping.
# WARNING:tensorflow:Early stopping conditioned on metric `val_acc` which is not available. Available metrics are: loss,accuracy,val_loss,val_accuracy
# 10/10 [==============================] - 49s 5s/step - loss: 0.0786 - accuracy: 0.9812 - val_loss: 0.2437 - val_accuracy: 0.9062
# Epoch 29/30
# 10/10 [==============================] - ETA: 0s - loss: 0.0833 - accuracy: 0.9750WARNING:tensorflow:Can save best model only with val_acc available, skipping.
# WARNING:tensorflow:Early stopping conditioned on metric `val_acc` which is not available. Available metrics are: loss,accuracy,val_loss,val_accuracy
# 10/10 [==============================] - 53s 5s/step - loss: 0.0833 - accuracy: 0.9750 - val_loss: 0.4254 - val_accuracy: 0.8750
# Epoch 30/30
# 10/10 [==============================] - ETA: 0s - loss: 0.0959 - accuracy: 0.9656WARNING:tensorflow:Can save best model only with val_acc available, skipping.
# WARNING:tensorflow:Early stopping conditioned on metric `val_acc` which is not available. Available metrics are: loss,accuracy,val_loss,val_accuracy
# 10/10 [==============================] - 50s 5s/step - loss: 0.0959 - accuracy: 0.9656 - val_loss: 0.2453 - val_accuracy: 0.9062

# %%
saved_model.save("final.2.h5")

# %%
saved_model = load_model(r"C:\Users\Jordan Lankford\OneDrive - University of Greenwich/AI/cw/my_model_usingsave_final_finetuned.h5")
test_score = saved_model.evaluate_generator(testdata, 2)
print("[INFO] accuracy: {:.2f}%".format(test_score[1] * 100))
print("[INFO] Loss: ",test_score[0])
# Out:
# WARNING:tensorflow:Error in loading the saved optimizer state. As a result, your model is starting with a freshly initialized optimizer.
# C:\Users\Jordan Lankford\AppData\Local\Temp\ipykernel_19364\4174750506.py:2: UserWarning: `Model.evaluate_generator` is deprecated and will be removed in a future version. Please use `Model.evaluate`, which supports generators.
#   test_score = saved_model.evaluate_generator(testdata, 2)
# [INFO] accuracy: 93.75%
# [INFO] Loss:  0.189716175198555

# %%
from keras.preprocessing import image
img = keras.utils.load_img(r"C:\Users\Jordan Lankford\OneDrive - University of Greenwich\AI\cw\just_peppers\predict\potato.JPG",target_size=(224,224))
img = np.asarray(img)
plt.imshow(img)
img = np.expand_dims(img, axis=0)
from keras.models import load_model
saved_model = load_model(r"C:\Users\Jordan Lankford\OneDrive - University of Greenwich/AI/cw/my_model_usingsave_final_finetuned.h5")
output = saved_model.predict(img)
print(output)
result = np.where(output == np.amax(output))
# print('max probabilliy:', result[1])
# print('found at index :', result[0])
value = {i for i in traindata.class_indices if traindata.class_indices[i]==result[1]}
print("label:",value)
# Out:
# WARNING:tensorflow:Error in loading the saved optimizer state. As a result, your model is starting with a freshly initialized optimizer.
# 1/1 [==============================] - 0s 362ms/step
# [[5.1337160e-05 4.6513890e-04 8.0156809e-05 9.5455151e-04 9.9828714e-01
#   4.0266932e-06 3.4323810e-05 3.1445165e-07 5.2791252e-06 1.2413070e-06
#   7.0025846e-05 3.1691430e-05 3.3347330e-06 3.4484660e-06 8.0462887e-06]]
# label: {'Potato___healthy'}

# %%
from sklearn.metrics import ConfusionMatrixDisplay
from sklearn.metrics import confusion_matrix
import matplotlib.pyplot as plt
import numpy as np

# %%
saved_model = load_model(r"C:\Users\Jordan Lankford\OneDrive - University of Greenwich/AI/cw/final.128.h5")
all_y_pred = []
all_y_true = []

for i in range(len(testdata)):
    x, y = testdata[i]
    y_pred = saved_model.predict(x)
    
    all_y_pred.append(y_pred)
    all_y_true.append(y)

all_y_pred = np.concatenate(all_y_pred, axis=0)
all_y_true = np.concatenate(all_y_true, axis=0)
# Out:
# 1/1 [==============================] - 4s 4s/step
# 1/1 [==============================] - 4s 4s/step
# 1/1 [==============================] - 4s 4s/step
# 1/1 [==============================] - 4s 4s/step
# 1/1 [==============================] - 5s 5s/step
# 1/1 [==============================] - 5s 5s/step
# 1/1 [==============================] - 5s 5s/step
# 1/1 [==============================] - 5s 5s/step
# 1/1 [==============================] - 5s 5s/step
# 1/1 [==============================] - 5s 5s/step
# 1/1 [==============================] - 5s 5s/step
# 1/1 [==============================] - 4s 4s/step
# 1/1 [==============================] - 5s 5s/step
# 1/1 [==============================] - 5s 5s/step
# 1/1 [==============================] - 5s 5s/step
# 1/1 [==============================] - 5s 5s/step
# 1/1 [==============================] - 4s 4s/step
# 1/1 [==============================] - 4s 4s/step
# 1/1 [==============================] - 5s 5s/step
# 1/1 [==============================] - 5s 5s/step
# 1/1 [==============================] - 5s 5s/step
# 1/1 [==============================] - 5s 5s/step
# 1/1 [==============================] - 5s 5s/step
# 1/1 [==============================] - 5s 5s/step
# 1/1 [==============================] - 5s 5s/step
# 1/1 [==============================] - 5s 5s/step
# 1/1 [==============================] - 5s 5s/step
# 1/1 [==============================] - 5s 5s/step
# 1/1 [==============================] - 5s 5s/step
# 1/1 [==============================] - 4s 4s/step
# 1/1 [==============================] - 5s 5s/step
# 1/1 [==============================] - 5s 5s/step
# 1/1 [==============================] - 5s 5s/step
# 1/1 [==============================] - 5s 5s/step
# 1/1 [==============================] - 5s 5s/step
# 1/1 [==============================] - 4s 4s/step
# 1/1 [==============================] - 5s 5s/step
# 1/1 [==============================] - 4s 4s/step
# 1/1 [==============================] - 4s 4s/step
# 1/1 [==============================] - 4s 4s/step
# 1/1 [==============================] - 4s 4s/step
# 1/1 [==============================] - 4s 4s/step
# 1/1 [==============================] - 5s 5s/step
# 1/1 [==============================] - 5s 5s/step
# 1/1 [==============================] - 5s 5s/step
# 1/1 [==============================] - 5s 5s/step
# 1/1 [==============================] - 5s 5s/step
# 1/1 [==============================] - 5s 5s/step
# 1/1 [==============================] - 5s 5s/step
# 1/1 [==============================] - 5s 5s/step
# 1/1 [==============================] - 5s 5s/step
# 1/1 [==============================] - 4s 4s/step
# 1/1 [==============================] - 4s 4s/step
# 1/1 [==============================] - 4s 4s/step
# 1/1 [==============================] - 4s 4s/step
# 1/1 [==============================] - 4s 4s/step
# 1/1 [==============================] - 4s 4s/step
# 1/1 [==============================] - 4s 4s/step
# 1/1 [==============================] - 4s 4s/step
# 1/1 [==============================] - 4s 4s/step
# 1/1 [==============================] - 4s 4s/step
# 1/1 [==============================] - 4s 4s/step
# 1/1 [==============================] - 4s 4s/step
# 1/1 [==============================] - 4s 4s/step
# 1/1 [==============================] - 4s 4s/step
# 1/1 [==============================] - 4s 4s/step
# 1/1 [==============================] - 4s 4s/step
# 1/1 [==============================] - 4s 4s/step
# 1/1 [==============================] - 5s 5s/step
# 1/1 [==============================] - 5s 5s/step
# 1/1 [==============================] - 5s 5s/step
# 1/1 [==============================] - 5s 5s/step
# 1/1 [==============================] - 5s 5s/step
# 1/1 [==============================] - 5s 5s/step
# 1/1 [==============================] - 5s 5s/step
# 1/1 [==============================] - 5s 5s/step
# 1/1 [==============================] - 4s 4s/step
# 1/1 [==============================] - 4s 4s/step
# 1/1 [==============================] - 4s 4s/step
# 1/1 [==============================] - 4s 4s/step
# 1/1 [==============================] - 4s 4s/step
# 1/1 [==============================] - 4s 4s/step
# 1/1 [==============================] - 4s 4s/step
# 1/1 [==============================] - 4s 4s/step
# 1/1 [==============================] - 4s 4s/step
# 1/1 [==============================] - 4s 4s/step
# 1/1 [==============================] - 4s 4s/step
# 1/1 [==============================] - 4s 4s/step
# 1/1 [==============================] - 4s 4s/step
# 1/1 [==============================] - 4s 4s/step
# 1/1 [==============================] - 4s 4s/step
# 1/1 [==============================] - 4s 4s/step
# 1/1 [==============================] - 4s 4s/step
# 1/1 [==============================] - 4s 4s/step
# 1/1 [==============================] - 5s 5s/step
# 1/1 [==============================] - 5s 5s/step
# 1/1 [==============================] - 5s 5s/step
# 1/1 [==============================] - 5s 5s/step
# 1/1 [==============================] - 5s 5s/step
# 1/1 [==============================] - 5s 5s/step
# 1/1 [==============================] - 5s 5s/step
# 1/1 [==============================] - 4s 4s/step
# 1/1 [==============================] - 4s 4s/step
# 1/1 [==============================] - 4s 4s/step
# 1/1 [==============================] - 4s 4s/step
# 1/1 [==============================] - 4s 4s/step
# 1/1 [==============================] - 4s 4s/step
# 1/1 [==============================] - 4s 4s/step
# 1/1 [==============================] - 4s 4s/step
# 1/1 [==============================] - 4s 4s/step
# 1/1 [==============================] - 4s 4s/step
# 1/1 [==============================] - 4s 4s/step
# 1/1 [==============================] - 4s 4s/step
# 1/1 [==============================] - 4s 4s/step
# 1/1 [==============================] - 4s 4s/step
# 1/1 [==============================] - 4s 4s/step
# 1/1 [==============================] - 4s 4s/step
# 1/1 [==============================] - 5s 5s/step
# 1/1 [==============================] - 4s 4s/step
# 1/1 [==============================] - 4s 4s/step
# 1/1 [==============================] - 5s 5s/step
# 1/1 [==============================] - 5s 5s/step
# 1/1 [==============================] - 5s 5s/step
# 1/1 [==============================] - 5s 5s/step
# 1/1 [==============================] - 5s 5s/step
# 1/1 [==============================] - 5s 5s/step
# 1/1 [==============================] - 5s 5s/step
# 1/1 [==============================] - 4s 4s/step
# 1/1 [==============================] - 4s 4s/step

# %%
y_true=np.argmax(all_y_true, axis=1)
y_pred = np.argmax(all_y_pred, axis=1)

# %%
from sklearn.metrics import confusion_matrix

# %%
cm = confusion_matrix(y_true, y_pred)

# %%
import seaborn as sn
import pandas as pd
import matplotlib.pyplot as plt

# %%
df_cm = pd.DataFrame(cm, traindata.class_indices.keys(), traindata.class_indices.keys())
plt.figure(figsize=(20,14))
sn.set(font_scale=1) # for label size
sn.heatmap(df_cm, annot=True, annot_kws={"size": 16},fmt='g') # font size

plt.show()
